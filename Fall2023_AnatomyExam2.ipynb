# %%
# importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

#Optional for disabling warnings 

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
df = pd.read_excel (r'./Exam2.xlsx') 
df.describe()
# Out:
#        Lecture_Exam2  Exam2_percent  Exam2_percent_curved  Exam2_outof12.5
# count      51.000000      52.000000             52.000000        51.000000
# mean       38.529412       0.575067              0.685067         8.563323
# std         9.681638       0.143078              0.143078         1.806276
# min        19.000000       0.283582              0.393582         4.919776
# 25%        32.000000       0.477612              0.587612         7.345149
# 50%        37.000000       0.552239              0.662239         8.277985
# 75%        45.500000       0.675373              0.785373         9.863806
# max        56.000000       0.835821              0.945821        11.822761

# %%
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x1 = df.Exam2_percent*100
plt.hist(x1, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Original Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,100)

plt.axvline(x1.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()))
# Out:
# Text(63.25731544232693, 5.67, 'Mean: 57.51')

# %%
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})

# Plot Histogram on x
x2 = df.Exam2_percent_curved*100
plt.hist(x2, bins = 25, edgecolor='k')
plt.gca().set(title='Frequency Histogram - Curved Score', ylabel='Frequency', xlabel = "Score (%)");
plt.xlim(0,102)

plt.axvline(x2.mean(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()))
# Out:
# Text(75.35731544232692, 5.67, 'Mean: 68.51')

# %%
kwargs = dict(hist_kws={'alpha':.4}, kde_kws={'linewidth':3})

plt.figure(figsize=(10,7), dpi= 300)
sns.distplot(x1, bins = 25, color="dodgerblue", label="Original", **kwargs)
plt.axvline(x1.mean(), color='dodgerblue', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x1.mean()*.75, max_ylim*0.9, 'Mean: {:.2f}'.format(x1.mean()), color="dodgerblue")

sns.distplot(x2, bins = 25, color="orange", label="Curved", **kwargs)
plt.axvline(x2.mean(), color='orange', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(x2.mean()*1.10, max_ylim*0.9, 'Mean: {:.2f}'.format(x2.mean()), color="orange")
plt.xlim(20,110)
plt.legend();
plt.gca().set(title='Fall 2023 Human Anatomy - Exam 2 Scores - Before and After Curve', ylabel='Density', xlabel='Score (%)')
# Out:
# [Text(0.5, 1.0, 'Fall 2023 Human Anatomy - Exam 2 Scores - Before and After Curve'),
#  Text(0, 0.5, 'Density'),
#  Text(0.5, 0, 'Score (%)')]
